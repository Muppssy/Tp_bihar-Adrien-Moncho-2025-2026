# %% [markdown]
# # Classification des images
#
# Ce notebook est dedie a la classification multi-label basee uniquement sur les images du projet BIHAR 2025.
#
# Objectifs du notebook :
# - preparer les donnees image a partir du dataset Kaggle,
# - construire et evaluer un CNN baseline,
# - experimenter avec des architectures CNN avancees,
# - comparer les resultats et analyser les predictions.

# %% [markdown]
# ## Plan du notebook

# %% [markdown]
# ## 1. Description synthetique du projet et des objectifs

# %%
from pathlib import Path
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Chargement des donnees

# %%
# importer de puis le bureau le dossier data avec les images 


IMAGE_DIR = Path(r"C:\Users\mupps\Desktop\COMP5329S1A2Dataset\data")
image_paths = sorted(IMAGE_DIR.glob("*.jpg"))

print("Nombre d'images :", len(image_paths))
print("Premiere image :", image_paths[0])

img = plt.imread(image_paths[0])

plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# Nombre d'images : 40000
# Premiere image : C:\Users\mupps\Desktop\COMP5329S1A2Dataset\data\0.jpg

# %% [markdown]
# ## 3. Analyse exploratoire des donnees

# %% [markdown]
# ### 3.1 Vue generale du dataset

# %% [markdown]
# ### 3.2 Analyse des labels

# %% [markdown]
# ### 3.3 Exploration visuelle des images

# %% [markdown]
# ### 3.4 Premiere lecture des relations image / labels

# %% [markdown]
# ## 4. Separation des donnees en train / validation / test
#
# Le projet demande une separation 70% / 15% / 15% a partir du fichier `train.csv` annote.

# %% [markdown]
# ## 5. Pretraitement des images

# %% [markdown]
# ### 5.1 Parametres de preprocessing

# %% [markdown]
# ### 5.2 Fonction de chargement et de preprocessing

# %% [markdown]
# ### 5.3 Construction des datasets TensorFlow

# %% [markdown]
# ## 6. Modelisation et evaluation des performances

# %% [markdown]
# ### 6.1 CNN baseline

# %% [markdown]
# ### 6.2 Metriques adaptees a la classification multi-label

# %% [markdown]
# ### 6.3 Diagnostic du sous-apprentissage / sur-apprentissage

# %% [markdown]
# ### 6.4 Evaluation sur le jeu de test

# %% [markdown]
# ### 6.5 Architectures CNN avancees

# %% [markdown]
# #### 6.5.1 Transfer learning

# %% [markdown]
# #### 6.5.2 Fine-tuning partiel

# %% [markdown]
# #### 6.5.3 Entrainement from scratch

# %% [markdown]
# ### 6.6 Comparaison des resultats et choix du modele final

# %% [markdown]
# ## 7. Analyse et interpretation des resultats

# %% [markdown]
# ### 7.1 Affichage de quelques predictions de test

# %% [markdown]
# ### 7.2 Interpretation avec LIME

# %% [markdown]
# ### 7.3 Analyse des erreurs

# %% [markdown]
# ### 7.4 Pistes d'amelioration
